# %%
from training_utils import TrainConfig, train_end_to_end, predict_proba, find_threshold_for_recall, print_reports, split_data, load_dataset_csv
import pandas as pd

# %%
df= pd.read_csv('fifth_feature_df_14_01_2026.csv')
df.head(5)
# Out:
#    SUBJECT_ID  HADM_ID  ICUSTAY_ID  GCS_max  GCS_mean  Lactate_min  \
# 0           3   145834      211552      6.0  4.444444          1.3
# 1           6   107064      228232      6.0  6.000000          NaN
# 2           9   150750      220597      5.0  2.600000          1.9
# 3          12   112213      232669      6.0  4.842105          1.6
# 4          17   194023      277042      6.0  5.615385          0.9
#
#    Lactate_max  Lactate_mean  BUN_min   BUN_mean  ...    HR_mean  HR_max  \
# 0          8.8      3.800000     36.0  40.500000  ...  98.925373   168.0
# 1          NaN           NaN     65.0  65.500000  ...  84.791667   100.0
# 2          2.7      2.380000     17.0  18.500000  ...  87.644737   111.0
# 3         15.1      8.716667     28.0  35.500000  ...  83.208333   105.0
# 4          0.9      0.900000     10.0  10.666667  ...  82.400000   114.0
#
#       HR_std  RDW_max   RDW_mean  RDW_min   RDW_std  \
# 0  28.103334     15.7  15.400000     15.0  0.273861
# 1   5.573334     17.0  16.450000     15.9  0.777817
# 2   8.162849     14.3  14.000000     13.8  0.264575
# 3   8.518311     14.9  14.625000     14.2  0.309570
# 4  11.049719     12.9  12.766667     12.6  0.152753
#
#    age_adj_comorbidity_score  MEANBP_min  MEANBP_mean
# 0                       16.0   40.000000    76.728071
# 1                       12.0   72.666702    87.175435
# 2                       12.0   67.000000    98.289474
# 3                        7.0   73.000000    96.819444
# 4                        0.0   53.000000    69.714286
#
# [5 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21247 entries, 0 to 21246
# Data columns (total 57 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SUBJECT_ID                 21247 non-null  int64
#  1   HADM_ID                    21247 non-null  int64
#  2   ICUSTAY_ID                 21247 non-null  int64
#  3   GCS_max                    20938 non-null  float64
#  4   GCS_mean                   20938 non-null  float64
#  5   Lactate_min                11893 non-null  float64
#  6   Lactate_max                11893 non-null  float64
#  7   Lactate_mean               11893 non-null  float64
#  8   BUN_min                    21076 non-null  float64
#  9   BUN_mean                   21076 non-null  float64
#  10  BUN_max                    21076 non-null  float64
#  11  Bilirubin_max              9322 non-null   float64
#  12  Bilirubin_mean             9322 non-null   float64
#  13  Albumin_mean               8021 non-null   float64
#  14  Albumin_min                8021 non-null   float64
#  15  Albumin_max                8021 non-null   float64
#  16  AlkPhos_mean               9088 non-null   float64
#  17  AlkPhos_max                9088 non-null   float64
#  18  AlkPhos_min                9088 non-null   float64
#  19  PT_mean                    18721 non-null  float64
#  20  PT_min                     18721 non-null  float64
#  21  INR_mean                   18723 non-null  float64
#  22  INR_min                    18723 non-null  float64
#  23  Phosphate_mean             19944 non-null  float64
#  24  Phosphate_max              19944 non-null  float64
#  25  PaO2_mean                  15037 non-null  float64
#  26  PaO2_max                   15037 non-null  float64
#  27  aPTT_mean                  18661 non-null  float64
#  28  aPTT_min                   18661 non-null  float64
#  29  MORTALITY_INHOSPITAL       21247 non-null  int64
#  30  MORTALITY_90DAY            21247 non-null  int64
#  31  MORTALITY_180DAY           21247 non-null  int64
#  32  AG_mean                    20965 non-null  float64
#  33  AG_max                     20965 non-null  float64
#  34  AG_min                     20965 non-null  float64
#  35  AG_std                     20085 non-null  float64
#  36  SYSBP_min                  20936 non-null  float64
#  37  SYSBP_mean                 20936 non-null  float64
#  38  SYSBP_std                  20933 non-null  float64
#  39  DIASBP_min                 20935 non-null  float64
#  40  DIASBP_mean                20935 non-null  float64
#  41  age                        21247 non-null  int64
#  42  RR_mean                    20930 non-null  float64
#  43  RR_max                     20930 non-null  float64
#  44  RR_min                     20930 non-null  float64
#  45  TEMP_std                   20714 non-null  float64
#  46  TEMP_min                   20775 non-null  float64
#  47  HR_mean                    20943 non-null  float64
#  48  HR_max                     20943 non-null  float64
#  49  HR_std                     20942 non-null  float64
#  50  RDW_max                    21028 non-null  float64
#  51  RDW_mean                   21028 non-null  float64
#  52  RDW_min                    21028 non-null  float64
#  53  RDW_std                    20373 non-null  float64
#  54  age_adj_comorbidity_score  21247 non-null  float64
#  55  MEANBP_min                 20941 non-null  float64
#  56  MEANBP_mean                20941 non-null  float64
# dtypes: float64(50), int64(7)
# memory usage: 9.2 MB

# %%
print(df.shape)
print(df.columns.to_list())
# Out:
# (21247, 57)
# ['SUBJECT_ID', 'HADM_ID', 'ICUSTAY_ID', 'GCS_max', 'GCS_mean', 'Lactate_min', 'Lactate_max', 'Lactate_mean', 'BUN_min', 'BUN_mean', 'BUN_max', 'Bilirubin_max', 'Bilirubin_mean', 'Albumin_mean', 'Albumin_min', 'Albumin_max', 'AlkPhos_mean', 'AlkPhos_max', 'AlkPhos_min', 'PT_mean', 'PT_min', 'INR_mean', 'INR_min', 'Phosphate_mean', 'Phosphate_max', 'PaO2_mean', 'PaO2_max', 'aPTT_mean', 'aPTT_min', 'MORTALITY_INHOSPITAL', 'MORTALITY_90DAY', 'MORTALITY_180DAY', 'AG_mean', 'AG_max', 'AG_min', 'AG_std', 'SYSBP_min', 'SYSBP_mean', 'SYSBP_std', 'DIASBP_min', 'DIASBP_mean', 'age', 'RR_mean', 'RR_max', 'RR_min', 'TEMP_std', 'TEMP_min', 'HR_mean', 'HR_max', 'HR_std', 'RDW_max', 'RDW_mean', 'RDW_min', 'RDW_std', 'age_adj_comorbidity_score', 'MEANBP_min', 'MEANBP_mean']

# %%
# Changeable values to train a different dataset.

DATASET_PATH = "fifth_feature_df_14_01_2026.csv"   # <-- change
TARGET_COL   = "MORTALITY_180DAY"                    # <-- change
DROP_COLS    = ["SUBJECT_ID", "HADM_ID", "ICUSTAY_ID",'MORTALITY_INHOSPITAL', 'MORTALITY_90DAY'] 
TARGET_RECALL = 0.90

cfg = TrainConfig(
    target_col=TARGET_COL,
    drop_cols=DROP_COLS,
    target_recall=TARGET_RECALL,
    test_size=0.2,
    random_state=42
)

# %%
# Train + Select Best Model (AP then AUROC)

results = train_end_to_end(DATASET_PATH, cfg)

best_name = results["best_name"]
best_model = results["best_model"]

metrics = results["metrics"]
X_val, y_val = results["val"]

print("Models trained:", list(metrics.keys()))
print("\nMetrics (threshold tuned for recall>=target):")
display(pd.DataFrame(metrics).T.sort_values(["ap", "auroc"], ascending=False))
# Out:
# Models trained: ['logreg', 'dt', 'rf', 'xgb']
#
# Metrics (threshold tuned for recall>=target):
#               ap     auroc  threshold
# xgb     0.659818  0.832783   0.148399
# logreg  0.612513  0.805590   0.312293
# rf      0.610614  0.818387   0.195000
# dt      0.496171  0.759199   0.325383

# %%
# Evaluate Best Model (Detailed Report)

y_prob = predict_proba(best_model, X_val)
thr = find_threshold_for_recall(y_val, y_prob, cfg.target_recall)

print(f"Best model: {best_name}")
print(f"Chosen threshold (target recall={cfg.target_recall}): {thr:.4f}\n")

print_reports(y_val, y_prob, threshold=thr)
# Out:
# Best model: xgb
# Chosen threshold (target recall=0.9): 0.1484
#
# Confusion matrix:
#  [[1703 1422]
#  [ 112 1013]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0     0.9383    0.5450    0.6895      3125
#            1     0.4160    0.9004    0.5691      1125
#
#     accuracy                         0.6391      4250
#    macro avg     0.6772    0.7227    0.6293      4250
# weighted avg     0.8000    0.6391    0.6576      4250

# %%
#Feature importance of XGBoost
import matplotlib.pyplot as plt

X, y= load_dataset_csv(DATASET_PATH, TARGET_COL, DROP_COLS)

X_train, X_val, y_train, y_val = split_data(
    X, y,
    test_size=cfg.test_size,
    random_state=cfg.random_state
)


#best_model = results["best_model"]
xgb_fitted = best_model.named_steps["model"]

importance = xgb_fitted.feature_importances_

print("Num columns in X_train:", X_train.shape[1])
print("Num importances:", len(importance))
print("Best model:", results["best_name"])


fi_xgb = pd.DataFrame({
    "feature": X_train.columns,
    "importance": importance
}).sort_values(by="importance", ascending=False)

print(fi_xgb)

# Plot top 20
plt.figure(figsize=(10, 6))
plt.barh(fi_xgb["feature"].head(20)[::-1],
         fi_xgb["importance"].head(20)[::-1])
plt.xlabel("Importance")
plt.title("XGBoost Feature Importance")
plt.tight_layout()
plt.show()
# Out:
# Num columns in X_train: 51
# Num importances: 51
# Best model: xgb
#                       feature  importance
# 48  age_adj_comorbidity_score    0.116927
# 0                     GCS_max    0.055991
# 45                   RDW_mean    0.053097
# 46                    RDW_min    0.044047
# 5                     BUN_min    0.038312
# 35                        age    0.034550
# 27                     AG_max    0.023413
# 36                    RR_mean    0.023069
# 10               Albumin_mean    0.022568
# 26                    AG_mean    0.022191
# 1                    GCS_mean    0.021306
# 14                AlkPhos_max    0.021114
# 12                Albumin_max    0.020460
# 9              Bilirubin_mean    0.018585
# 44                    RDW_max    0.018440
# 31                 SYSBP_mean    0.017621
# 4                Lactate_mean    0.017603
# 2                 Lactate_min    0.017387
# 28                     AG_min    0.016915
# 15                AlkPhos_min    0.016228
# 40                   TEMP_min    0.015758
# 6                    BUN_mean    0.015576
# 23                   PaO2_max    0.015014
# 39                   TEMP_std    0.014501
# 3                 Lactate_max    0.014389
# 41                    HR_mean    0.014244
# 50                MEANBP_mean    0.013736
# 18                   INR_mean    0.013336
# 32                  SYSBP_std    0.013190
# 13               AlkPhos_mean    0.013173
# 49                 MEANBP_min    0.012648
# 30                  SYSBP_min    0.012472
# 24                  aPTT_mean    0.012446
# 38                     RR_min    0.012407
# 42                     HR_max    0.012292
# 34                DIASBP_mean    0.012168
# 22                  PaO2_mean    0.012049
# 43                     HR_std    0.011814
# 19                    INR_min    0.011752
# 25                   aPTT_min    0.011744
# 8               Bilirubin_max    0.011365
# 33                 DIASBP_min    0.011354
# 20             Phosphate_mean    0.011122
# 29                     AG_std    0.011107
# 21              Phosphate_max    0.010596
# 7                     BUN_max    0.010499
# 11                Albumin_min    0.010482
# 17                     PT_min    0.010341
# 16                    PT_mean    0.009902
# 47                    RDW_std    0.009519
# 37                     RR_max    0.009182

# %%
# SHAP summary plot showing global feature importance for the final XGBoost model
import shap

explainer = shap.TreeExplainer(xgb_fitted)
shap_values = explainer.shap_values(X_train)

shap.summary_plot(shap_values, X_train, plot_type="bar")

# %%
# Create joblib file
from pathlib import Path
import joblib

BASE_DIR = Path.cwd()   
MODEL_DIR = BASE_DIR / "models"
MODEL_DIR.mkdir(exist_ok=True)

model_path = MODEL_DIR / "fifth_feature_mortality_180days.joblib"


joblib.dump(best_model, model_path)

print(f"Model saved at: {model_path}")
# Out:
# Model saved at: d:\Python Essential\Data Science II project\Fifh_feature\models\fifth_feature_mortality_180days.joblib
